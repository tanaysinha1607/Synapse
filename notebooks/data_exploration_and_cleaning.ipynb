# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import os
from scipy import stats

# %%
df= pd.read_csv("../data/raw/dataset_synapse.csv")

# %%
df.head()
# Out:
#              JobTitle      Standard_Title                       CompanyName  \
# 0   Software Engineer   Software Engineer                            Google
# 1   Software Engineer   Software Engineer  Hewlett Packard Enterprise (HPE)
# 2   Software Engineer   Software Engineer                     Coriolis Tech
# 3  Software Developer  Software Developer                            Tetcos
# 4  Software Developer  Software Developer                            Amazon
#
#               Location Salary_Range_INR (lakhs)  \
# 0  Gurugram, Bengaluru                 27.8-48
# 1            Bengaluru                9.8- 17.2
# 2                 Pune                 3.5- 5.5
# 3            Bengaluru                   4- 5.7
# 4              Chennai                 20.2- 34
#
#                                      Skills_Required Posting_Date  \
# 0  Unix, C++, Linux, Networking, Machine learning...      1 month
# 1  Computer science, Development Manager, Coding,...       1 week
# 2  Github, Debugging, Software Development, Life ...        1 day
# 3  C#, Multi Treading, C Coding, Networking Proto...        1 day
# 4  Unix, Computer science, Object oriented design...      1 month
#
#                                           Source_URL  role_volume
# 0  https://www.naukri.com/job-listings-software-e...       102707
# 1  https://www.naukri.com/job-listings-graduate-s...       102707
# 2  https://www.naukri.com/job-listings-hiring-for...       102707
# 3  https://www.naukri.com/job-listings-software-d...        98619
# 4  https://www.naukri.com/job-listings-software-d...        98619

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   JobTitle                  35 non-null     object
#  1   Standard_Title            35 non-null     object
#  2   CompanyName               35 non-null     object
#  3   Location                  35 non-null     object
#  4   Salary_Range_INR (lakhs)  35 non-null     object
#  5   Skills_Required           35 non-null     object
#  6   Posting_Date              35 non-null     object
#  7   Source_URL                35 non-null     object
#  8   role_volume               35 non-null     int64
# dtypes: int64(1), object(8)
# memory usage: 2.6+ KB

# %%
def clean_salary(salary_range):
    low, high = [float(s.strip()) for s in salary_range.split('-')]
    return (low + high) / 2 * 100000

df['avg_salary_inr'] = df['Salary_Range_INR (lakhs)'].apply(clean_salary)

# %%
def parse_skills(skills_text):
    if not isinstance(skills_text, str):
        return []
    cleaned_text = skills_text.replace('\n', ' ').strip()

    skills_list = [skill.strip() for skill in cleaned_text.split(',')]
    return skills_list

df['skills_list'] = df['Skills_Required'].apply(parse_skills)

# %%
def standardize_date(date_str):
    if not isinstance(date_str, str):
        return pd.NaT # Not a Time for missing values
    
    today = datetime.now()
    date_str = date_str.lower()
    
    try:
        if 'day' in date_str:
            days_ago = int(date_str.split()[0])
            return today - timedelta(days=days_ago)
        elif 'week' in date_str:
            weeks_ago = int(date_str.split()[0])
            return today - timedelta(weeks=weeks_ago)
        elif 'month' in date_str:
            months_ago = int(date_str.split()[0])
            # Approximation: 30 days per month
            return today - timedelta(days=months_ago * 30)
        else:
            return pd.NaT # Return NaT if format is not recognized
    except (ValueError, IndexError):
        return pd.NaT

df['standard_date'] = df['Posting_Date'].apply(standardize_date)

# %%
df_cleaned = df.drop(columns=['Salary_Range_INR (lakhs)', 'Skills_Required', 'Posting_Date'])

# %%
df_cleaned.head()
# Out:
#              JobTitle      Standard_Title                       CompanyName  \
# 0   Software Engineer   Software Engineer                            Google
# 1   Software Engineer   Software Engineer  Hewlett Packard Enterprise (HPE)
# 2   Software Engineer   Software Engineer                     Coriolis Tech
# 3  Software Developer  Software Developer                            Tetcos
# 4  Software Developer  Software Developer                            Amazon
#
#               Location                                         Source_URL  \
# 0  Gurugram, Bengaluru  https://www.naukri.com/job-listings-software-e...
# 1            Bengaluru  https://www.naukri.com/job-listings-graduate-s...
# 2                 Pune  https://www.naukri.com/job-listings-hiring-for...
# 3            Bengaluru  https://www.naukri.com/job-listings-software-d...
# 4              Chennai  https://www.naukri.com/job-listings-software-d...
#
#    role_volume  avg_salary_inr  \
# 0       102707       3790000.0
# 1       102707       1350000.0
# 2       102707        450000.0
# 3        98619        485000.0
# 4        98619       2710000.0
#
#                                          skills_list  \
# 0  [Unix, C++, Linux, Networking, Machine learnin...
# 1  [Computer science, Development Manager, Coding...
# 2  [Github, Debugging, Software Development, Life...
# 3  [C#, Multi Treading, C Coding, Networking Prot...
# 4  [Unix, Computer science, Object oriented desig...
#
#                standard_date
# 0 2025-08-07 21:52:33.490587
# 1 2025-08-30 21:52:33.490587
# 2 2025-09-05 21:52:33.490587
# 3 2025-09-05 21:52:33.490587
# 4 2025-08-07 21:52:33.490587

# %%
def get_trend_slope(csv_file_path):
    try:
        trends_df = pd.read_csv(csv_file_path, skiprows=2)
        trends_df.columns = ['Month', 'Interest']
        trends_df['Interest'] = pd.to_numeric(trends_df['Interest'], errors='coerce').fillna(0)
        trends_df['Time_Index'] = range(len(trends_df))
        
        # Perform linear regression to find the slope
        slope, intercept, r_value, p_value, std_err = stats.linregress(
            trends_df['Time_Index'],
            trends_df['Interest']
        )
        return slope
    except FileNotFoundError:
        print(f"Warning: File not found at {csv_file_path}. Returning slope of 0.")
        return 0
    except Exception as e:
        print(f"An error occurred with file {csv_file_path}: {e}")
        return 0

# %%
trends_file_mapping = {
    "Software Engineer": "../data/raw/trends/trends_software_engineer.csv",
    "Software Developer": "../data/raw/trends/trends_software_developer.csv",
    "Frontend Developer" : "../data/raw/trends/trends_frontend_developer.csv",
    "FullStack Developer" : "../data/raw/trends/trends_fullstack_developer.csv",
    "Backend Developer" : "../data/raw/trends/trends_backend_developer.csv",
    "Data Analyst": "../data/raw/trends/trends_data_analyst.csv",
    "AI/ML Engineer": "../data/raw/trends/trends_aiml_engineer.csv",
    "DevOps": "../data/raw/trends/trends_devops.csv",
    "CyberSecurity Analyst" : "../data/raw/trends/trends_cybersecurity_analyst.csv",
    "Business Analyst" : "../data/raw/trends/trends_business_analyst.csv",
    "App Developer" : "../data/raw/trends/trends_app_developer.csv",
    "Software Tester" : "../data/raw/trends/trends_software_tester.csv",
    "Technical Support" : "../data/raw/trends/trends_technical_support.csv", 
    "Network Engineer" : "../data/raw/trends/trends_network_engineer.csv" ,
    "Product Engineer" : "../data/raw/trends/trends_product_engineer.csv"
}

# %%
df_cleaned['fgm_score'] = df_cleaned['Standard_Title'].apply(
    lambda x: get_trend_slope(trends_file_mapping.get(x, None)) if trends_file_mapping.get(x) else 0
)

# %%
df_cleaned.groupby('Standard_Title')['fgm_score'].first()
# Out:
# Standard_Title
# AI/ML Engineer           0.236254
# App Developer            0.055563
# Backend Developer        0.233981
# Business Analyst         0.016538
# CyberSecurity Analyst    0.289981
# Data Analyst             0.165257
# DevOps                   0.118873
# Frontend Developer       0.344176
# FullStack Developer      0.289331
# Network Engineer         0.115382
# Product Engineer         0.127651
# Software Developer       0.007628
# Software Engineer        0.465592
# Software Tester         -0.020765
# Technical Support        0.034056
# Name: fgm_score, dtype: float64

# %%
df_cleaned
# Out:
#                                              JobTitle         Standard_Title  \
# 0                                   Software Engineer      Software Engineer
# 1                                   Software Engineer      Software Engineer
# 2                                   Software Engineer      Software Engineer
# 3                                  Software Developer     Software Developer
# 4                                  Software Developer     Software Developer
# 5                                  Software Developer     Software Developer
# 6                      JavaScript front end developer     Frontend Developer
# 7                                  Frontend Developer     Frontend Developer
# 8                                  Frontend Developer     Frontend Developer
# 9               Fullstack Web Developer (MERN/Django)    FullStack Developer
# 10                                FullStack Developer    FullStack Developer
# 11                          Mern Full Stack Developer    FullStack Developer
# 12                       Back-End Developer - Fresher      Backend Developer
# 13                                       Data Analyst           Data Analyst
# 14                           Analytics - Data Analyst           Data Analyst
# 15                                       Data Analyst           Data Analyst
# 16                  Artificial Intelligence Developer         AI/ML Engineer
# 17                   Artificial Intelligence Engineer         AI/ML Engineer
# 18                  AI/ML Engineer at Rely Healthtech         AI/ML Engineer
# 19                                    DevOps Engineer                 DevOps
# 20            Associate Software Engineer II - DevOps                 DevOps
# 21                                    DevOps Engineer                 DevOps
# 22  Software Development, Testing, Se- curity Asse...  CyberSecurity Analyst
# 23                                   Business Analyst       Business Analyst
# 24              Business Analyst - Sourcing Associate       Business Analyst
# 25                       Mobile Application Developer          App Developer
# 26                                    Software Tester        Software Tester
# 27                             Software Test Engineer        Software Tester
# 28  Software Tester, QA, Manual, Automation - Fres...        Software Tester
# 29                            IT Service Desk Analyst      Technical Support
# 30      International Service Desk/ Technical Support      Technical Support
# 31                           Network Engineer Fresher       Network Engineer
# 32                           Network Engineer Fresher       Network Engineer
# 33          Product Sourcing Engineer - X Ray Devices       Product Engineer
# 34                           Product Support Engineer       Product Engineer
#
#                                        CompanyName  \
# 0                                           Google
# 1                 Hewlett Packard Enterprise (HPE)
# 2                                    Coriolis Tech
# 3                                           Tetcos
# 4                                           Amazon
# 5                                            Nokia
# 6                                 Avom Consultants
# 7                           All In One Consultancy
# 8                   Nasiwak Services India Pvt Ltd
# 9          Krishworks Technology And Research Labs
# 10                               Morpheme Webnexus
# 11                                        Acciojob
# 12                                        ti Steps
# 13                                American Express
# 14                                   Deutsche Bank
# 15                                        Acciojob
# 16                    SmartDocs Business Solutions
# 17                            Gizmeon Technologies
# 18                    Rely Healthcare Technologies
# 19                                       Thyrocare
# 20                                           Optum
# 21                                Serviam Manpower
# 22  National Institute for Smart Government (NISG)
# 23                             JPMorgan Chase Bank
# 24                               Babaclick Trading
# 25                                    Valtrium Llc
# 26                       vhr Professional Services
# 27                                    Salescode.ai
# 28                                   Amar InfoTech
# 29                                           Wipro
# 30                             KVC CONSULTANTS LTD
# 31        Oasis Technology And Consulting Services
# 32                        Networkkings It Services
# 33                                         Philips
# 34                             Baldor Technologies
#
#                          Location  \
# 0             Gurugram, Bengaluru
# 1                       Bengaluru
# 2                            Pune
# 3                       Bengaluru
# 4                         Chennai
# 5                       Bengaluru
# 6                       Bengaluru
# 7                          Nagpur
# 8                       Bengaluru
# 9                       Bengaluru
# 10                          Noida
# 11     Hyderabad, Pune, Bengaluru
# 12  Hyderabad, Chennai, Bengaluru
# 13                       Gurugram
# 14                         Mumbai
# 15                      Bengaluru
# 16                      Bengaluru
# 17                          Kochi
# 18                       Gurugram
# 19                      Bengaluru
# 20                          Noida
# 21                         Mumbai
# 22                      Bengaluru
# 23                      Bengaluru
# 24                       Gurugram
# 25                      Bengaluru
# 26                         Remote
# 27                       Gurugram
# 28                      Ahemdabad
# 29   Kolkata, Gurugram, Hyderabad
# 30     Hyderabad, Pune, Bengaluru
# 31  Tirupati, Chennai, Coimbatore
# 32   Noida, Gurugram, Delhi / NCR
# 33                           Pune
# 34                         Mumbai
#
#                                            Source_URL  role_volume  \
# 0   https://www.naukri.com/job-listings-software-e...       102707
# 1   https://www.naukri.com/job-listings-graduate-s...       102707
# 2   https://www.naukri.com/job-listings-hiring-for...       102707
# 3   https://www.naukri.com/job-listings-software-d...        98619
# 4   https://www.naukri.com/job-listings-software-d...        98619
# 5   https://www.naukri.com/job-listings-software-d...        98619
# 6   https://www.naukri.com/job-listings-javascript...        38966
# 7   https://www.naukri.com/job-listings-front-end-...        38966
# 8   https://www.naukri.com/job-listings-front-end-...        38966
# 9   https://www.naukri.com/job-listings-fullstack-...         2270
# 10  https://www.naukri.com/job-listings-fullstack-...         2270
# 11  https://www.naukri.com/job-listings-mern-full-...         2270
# 12  https://www.naukri.com/job-listings-back-end-d...       116536
# 13  https://www.naukri.com/job-listings-data-analy...         2406
# 14  https://www.naukri.com/job-listings-analytics-...         2406
# 15  https://www.naukri.com/job-listings-data-analy...         2406
# 16  https://www.naukri.com/job-listings-artificial...        18105
# 17  https://www.naukri.com/job-listings-artificial...        18105
# 18  https://www.naukri.com/job-listings-ai-ml-engi...        18105
# 19  https://www.naukri.com/job-listings-devops-eng...          633
# 20  https://www.naukri.com/job-listings-associate-...          633
# 21  https://www.naukri.com/job-listings-devops-eng...          633
# 22  https://www.naukri.com/job-listings-software-d...         1090
# 23  https://www.naukri.com/job-listings-business-a...         1083
# 24  https://www.naukri.com/job-listings-business-a...         1083
# 25  https://www.naukri.com/job-listings-mobile-app...         1096
# 26  https://www.naukri.com/job-listings-software-t...        20933
# 27  https://www.naukri.com/job-listings-software-t...        20933
# 28  https://www.naukri.com/job-listings-software-t...        20933
# 29  https://www.naukri.com/job-listings-it-service...         2848
# 30  https://www.naukri.com/job-listings-internatio...         2848
# 31  https://www.naukri.com/job-listings-network-en...          569
# 32  https://www.naukri.com/job-listings-network-en...          569
# 33  https://www.naukri.com/job-listings-product-so...         1399
# 34  https://www.naukri.com/job-listings-product-su...         1399
#
#     avg_salary_inr                                        skills_list  \
# 0        3790000.0  [Unix, C++, Linux, Networking, Machine learnin...
# 1        1350000.0  [Computer science, Development Manager, Coding...
# 2         450000.0  [Github, Debugging, Software Development, Life...
# 3         485000.0  [C#, Multi Treading, C Coding, Networking Prot...
# 4        2710000.0  [Unix, Computer science, Object oriented desig...
# 5         845000.0  [c++, rtos, linux, debugging, software develop...
# 6        1700000.0  [css, react js, Ember.Js, Rxjs, Backbone.Js, V...
# 7         362500.0  [Frontend Development, Typescript, Javascript,...
# 8         450000.0          [Python, CSS, Javascript, HTML, React.Js]
# 9         600000.0  [Mern Stack, coding, Mean Stack, Django, probl...
# 10        212500.0  [Langchain, Huggingface, MongoDB, React.Js, AW...
# 11        800000.0     [DSA, Javascript, Node.Js, React.Js, Expresjs]
# 12        350000.0  [Backend, Restfull Api, Postgresql, MySQL, Mon...
# 13       1745000.0                   [Power Bi, Tableau, SQL, Python]
# 14        725000.0  [ms access, sql, vba, ssrs, ssis, python, syba...
# 15        700000.0  [Aptitude, Excel, Power Bi, Problem Solving, SQL]
# 16       1100000.0  [SAS, ChemBerta, Artificial Intelligence, LLM,...
# 17       1000000.0  [Tensorflow, Artificial Intelligence, Natural ...
# 18       1025000.0  [Deep Learning, Tensorflow, Object Detection, ...
# 19        950000.0  [Cloud, Python, Kubernetes, Ci Cd Pipeline, Gi...
# 20       1000000.0                        [Unix, Github, Devops, SQL]
# 21        400000.0          [Linux Administration, Linux, Aws Devops]
# 22       1000000.0  [Software Development, Security Assessment, Te...
# 23       1480000.0  [Excel, Operational risk, Legal compliance, Co...
# 24        540000.0  [Communication Skills, Excellent Verbal And Wr...
# 25        720000.0  [Swift Ui, Flutter, React Native, IOS, English...
# 26       2500000.0  [QA Testing, Software Testing, Software, Manua...
# 27        750000.0  [Java, QA Testing, Software Testing, Selenium,...
# 28        375000.0  [Software Testing, Manual Testing, fresherAuto...
# 29        460000.0  [Service Desk, L1 Support, Helpdesk, Desktop S...
# 30        500000.0  [Service Desk, International, TECH MAHINDRA, I...
# 31        550000.0  [Network Support, CCNA, Desktop Support, AWS, ...
# 32        450000.0  [Hardware Networking, Network Support, CCNA, D...
# 33        750000.0  [Process optimization, Project management, Pro...
# 34        525000.0  [Product Support, Ticketing Tools, SQL Queries...
#
#                 standard_date  fgm_score
# 0  2025-08-07 21:52:33.490587   0.465592
# 1  2025-08-30 21:52:33.490587   0.465592
# 2  2025-09-05 21:52:33.490587   0.465592
# 3  2025-09-05 21:52:33.490587   0.007628
# 4  2025-08-07 21:52:33.490587   0.007628
# 5  2025-08-23 21:52:33.490587   0.007628
# 6  2025-08-30 21:52:33.490587   0.344176
# 7  2025-08-30 21:52:33.490587   0.344176
# 8  2025-08-30 21:52:33.490587   0.344176
# 9  2025-08-16 21:52:33.490587   0.289331
# 10 2025-09-05 21:52:33.490587   0.289331
# 11 2025-09-04 21:52:33.490587   0.289331
# 12 2025-08-30 21:52:33.490587   0.233981
# 13 2025-08-30 21:52:33.490587   0.165257
# 14 2025-08-16 21:52:33.490587   0.165257
# 15 2025-08-23 21:52:33.490587   0.165257
# 16 2025-08-30 21:52:33.490587   0.236254
# 17 2025-08-16 21:52:33.490587   0.236254
# 18 2025-09-05 21:52:33.490587   0.236254
# 19 2025-08-16 21:52:33.490587   0.118873
# 20 2025-08-30 21:52:33.490587   0.118873
# 21 2025-08-30 21:52:33.490587   0.118873
# 22 2025-08-31 21:52:33.490587   0.289981
# 23 2025-09-04 21:52:33.490587   0.016538
# 24 2025-09-05 21:52:33.490587   0.016538
# 25 2025-09-05 21:52:33.490587   0.055563
# 26 2025-09-02 21:52:33.490587  -0.020765
# 27 2025-08-07 21:52:33.490587  -0.020765
# 28 2025-08-23 21:52:33.490587  -0.020765
# 29 2025-08-23 21:52:33.490587   0.034056
# 30 2025-08-23 21:52:33.490587   0.034056
# 31 2025-08-07 21:52:33.490587   0.115382
# 32 2025-09-02 21:52:33.490587   0.115382
# 33 2025-08-07 21:52:33.490587   0.127651
# 34 2025-08-07 21:52:33.490587   0.127651

# %%
output_path = '../data/processed/market_intelligence_db.csv'
os.makedirs(os.path.dirname(output_path), exist_ok=True)
df_cleaned.to_csv(output_path, index=False)
